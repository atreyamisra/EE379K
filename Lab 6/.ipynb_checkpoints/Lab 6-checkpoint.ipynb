# %% [markdown]
#  Hari Kosuru, hk8663,
#  Atreya Misra, am73676

# %%
import numpy as np
import pandas as pd

import random
from math import sqrt

import matplotlib.pyplot as plt

# %% [markdown]
# Problem 1: K-Means

# %%
# Generate a random initialization
numPoints = 200
numClusters = 6
min = 0
max = 9
generatedPoints = []
converged = False

random.seed(40)
threshHold = .1


def pythag(p1, p2):
    return sqrt((p1[0] - p2[0]) ** 2 + (p1[1] - p2[1]) ** 2)


for i in range(0, numPoints):
    generatedPoints.append([random.uniform(min, max), random.uniform(min, max)])

copyOfPoints = generatedPoints

# Generate the initial k-means(randomly)
means = []
centroids = []
clusters = []

for i in range(0, numClusters):
    potentialMean = [random.uniform(min, max), random.uniform(min, max)]
    while potentialMean in means:
        potentialMean = [random.uniform(min, max), random.uniform(min, max)]
    means.append(potentialMean)

while not converged:
    clusters = [[] for _ in range(numClusters)]
    for i in range(0, len(copyOfPoints)):
        dists = []
        for j in range(0, numClusters):
            dists.append(pythag(generatedPoints[i], means[j]))
            # print dists
        minIndex = np.argmin(dists)
        (clusters[minIndex]).append(copyOfPoints[i])

        # calculate centroids
    centroids = []
    for i in range(0, numClusters):
        thisCluster = clusters[i]
        centroids.append([np.mean([x[0] for x in thisCluster]), np.mean([x[1] for x in thisCluster])])

    diff = 0.0
    converged = True
    for i in range(0, numClusters):
        diff = pythag(centroids[i], means[i])
        print 'Difference between mean and centroid of ' + str(i) + ': ' + str(diff)
        if diff > threshHold:
            converged = False

    if not converged:
        means = centroids

# x_val = [x[0] for x in generatedPoints]
# y_val = [y[1] for y in generatedPoints]
#
# plt.scatter(x_val, y_val, label='Generated Points')

colors = ['r', 'b', 'g', 'y', 'c', 'm', 'y']
for i in range(0, numClusters):
    x_val = [x[0] for x in clusters[i]]
    y_val = [y[1] for y in clusters[i]]

    plt.scatter(x_val, y_val, color=colors[i], label='Cluster ' + str(i))

# x_val = [x[0] for x in means]
# y_val = [y[1] for y in means]
#
# plt.scatter(x_val, y_val, marker='x', label='Initial Means')

x_val = [x[0] for x in centroids]
y_val = [y[1] for y in centroids]

plt.scatter(x_val, y_val, marker='x', color='k', s=50, label='Final Means')
plt.title('Generated Points with Initial Means')
plt.legend()
plt.show()

# print 'Generated Points(Randomized):\n', np.asarray(generatedPoints)
print '\nGenerated Means(Randomized):\n', means
print '\nCalculated Clusters:\n', clusters
print '\nCalculated Centroids:\n', centroids
# Out:
# Difference between mean and centroid of 0: 0.379022186022
# Difference between mean and centroid of 1: 1.59286313062
# Difference between mean and centroid of 2: 2.68800309235
# Difference between mean and centroid of 3: 2.95598835264
# Difference between mean and centroid of 4: 0.990381338551
# Difference between mean and centroid of 5: 1.90233457027
# Difference between mean and centroid of 0: 0.468248863217
# Difference between mean and centroid of 1: 0.356621872518
# Difference between mean and centroid of 2: 0.819335847235
# Difference between mean and centroid of 3: 0.304226912181
# Difference between mean and centroid of 4: 0.450719922741
# Difference between mean and centroid of 5: 1.34422071796
# Difference between mean and centroid of 0: 0.452956601215
# Difference between mean and centroid of 1: 0.0178236574478
# Difference between mean and centroid of 2: 0.506039880297
# Difference between mean and centroid of 3: 0.102092404592
# Difference between mean and centroid of 4: 0.502721399117
# Difference between mean and centroid of 5: 0.672790558677
# Difference between mean and centroid of 0: 0.342984379152
# Difference between mean and centroid of 1: 0.308202181559
# Difference between mean and centroid of 2: 0.134065367078
# Difference between mean and centroid of 3: 0.137489034012
# Difference between mean and centroid of 4: 0.333580887091
# Difference between mean and centroid of 5: 0.300499643971
# Difference between mean and centroid of 0: 0.274537812704
# Difference between mean and centroid of 1: 0.200848029184
# Difference between mean and centroid of 2: 0.157133039186
# Difference between mean and centroid of 3: 0.0
# Difference between mean and centroid of 4: 0.161444264247
# Difference between mean and centroid of 5: 0.417377801784
# Difference between mean and centroid of 0: 0.138117490562
# Difference between mean and centroid of 1: 0.0912099463498
# Difference between mean and centroid of 2: 0.197307971064
# Difference between mean and centroid of 3: 0.0
# Difference between mean and centroid of 4: 0.0747879665854
# Difference between mean and centroid of 5: 0.314146624328
# Difference between mean and centroid of 0: 0.257090133169
# Difference between mean and centroid of 1: 0.0549746549546
# Difference between mean and centroid of 2: 0.173966276609
# Difference between mean and centroid of 3: 0.120779654797
# Difference between mean and centroid of 4: 0.0
# Difference between mean and centroid of 5: 0.090381298378
# Difference between mean and centroid of 0: 0.163192089291
# Difference between mean and centroid of 1: 0.0820308104187
# Difference between mean and centroid of 2: 0.206925037773
# Difference between mean and centroid of 3: 0.0749731461258
# Difference between mean and centroid of 4: 0.0827647684754
# Difference between mean and centroid of 5: 0.176945839959
# Difference between mean and centroid of 0: 0.0958197566229
# Difference between mean and centroid of 1: 0.0745881459141
# Difference between mean and centroid of 2: 0.0733183892886
# Difference between mean and centroid of 3: 0.0
# Difference between mean and centroid of 4: 0.14993362038
# Difference between mean and centroid of 5: 0.187692454404
# Difference between mean and centroid of 0: 0.0526690924448
# Difference between mean and centroid of 1: 0.0486887077886
# Difference between mean and centroid of 2: 0.0698035781529
# Difference between mean and centroid of 3: 0.0
# Difference between mean and centroid of 4: 0.105719911618
# Difference between mean and centroid of 5: 0.0915872765308
# Difference between mean and centroid of 0: 0.0
# Difference between mean and centroid of 1: 0.0724522995196
# Difference between mean and centroid of 2: 0.0724873510571
# Difference between mean and centroid of 3: 0.0
# Difference between mean and centroid of 4: 0.0
# Difference between mean and centroid of 5: 0.172247297874
# Difference between mean and centroid of 0: 0.0
# Difference between mean and centroid of 1: 0.0929505274044
# Difference between mean and centroid of 2: 0.0
# Difference between mean and centroid of 3: 0.0
# Difference between mean and centroid of 4: 0.111788006164
# Difference between mean and centroid of 5: 0.0
# Difference between mean and centroid of 0: 0.0
# Difference between mean and centroid of 1: 0.0
# Difference between mean and centroid of 2: 0.0
# Difference between mean and centroid of 3: 0.0
# Difference between mean and centroid of 4: 0.0
# Difference between mean and centroid of 5: 0.0
# Generated Means(Randomized):
# [[4.0037421478899553, 4.8085887179052342], [7.7514547323925154, 2.9788330983111493], [1.4566989740598586, 6.864897132488081], [1.3170406910440038, 2.0007871132260786], [5.1484214222498732, 1.5504365264918705], [6.4782653146659319, 7.4088665378677625]]
#
# Calculated Clusters:
# [[[5.576218712062262, 4.145994735129842], [5.483491533582951, 5.267895386223108], [2.5652105779748307, 4.79995075772348], [3.772590324638446, 3.8729093221086046], [3.5425253873112474, 6.029035478534175], [3.836614697300833, 4.725658450248254], [4.273701237879206, 5.750003526702667], [5.296919738030488, 5.046576591926327], [3.027654798183529, 5.417572332261793], [4.351703146957035, 6.17657869853698], [5.387702540195474, 3.509620159584608], [4.8482175930875515, 3.88406732717786], [4.7110291634058195, 5.407471649752799], [2.674191129835436, 4.443088863005106], [4.234700978733018, 4.252990553750221], [5.466433120484404